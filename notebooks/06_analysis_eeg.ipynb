# %% [markdown]
# # 06 • EEG × KEC
# Band-power association with KEC metrics.

# %%
from pathlib import Path
import pandas as pd
proc = Path('data/processed')
df = pd.read_csv(proc/'zuco_aligned.csv')
cols = ['theta1','alpha1','beta1','gamma1','entropy','curvature','coherence']
avail = [c for c in cols if c in df.columns]
print('Available:', avail)
corr = df[avail].corr() if avail else pd.DataFrame()
corr.round(3)

# %%
# Save correlation heatmap (if any)
import numpy as np, matplotlib.pyplot as plt, os
if 'corr' in globals() and hasattr(corr, 'values') and corr.size>0:
    fig, ax = plt.subplots(figsize=(4,3))
    im = ax.imshow(corr.values, cmap='coolwarm', vmin=-1, vmax=1)
    ax.set_xticks(range(len(corr.columns))); ax.set_xticklabels(list(corr.columns), rotation=45, ha='right')
    ax.set_yticks(range(len(corr.index))); ax.set_yticklabels(list(corr.index))
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    os.makedirs('figures', exist_ok=True)
    fig.tight_layout()
    fig.savefig('figures/F3_eeg_corr.png', dpi=150)
    plt.close(fig)
